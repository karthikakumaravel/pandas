# %%
import numpy as np
import pandas as pd

# %%
a=np.array([1,2,3])
a
# Out:
# array([1, 2, 3])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
import pandas as pd
s=pd.Series([10,20,30,40])
print(s)
print(type(s))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
s[3]
# Out:
# 40

# %%
import pandas as pd
s=pd.Series([10,20,30,40])
s.drop(1,inplace=True)#remove
print(s)
# Out:
# 0    10
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
s=pd.Series([10,20,30,40])
s.iloc[2]
# Out:
# 30

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
import pandas as pd
s=pd.Series([10,20,30,40,50],index=['k','k','r','t','h'])
print(s)
# Out:
# k    10
# k    20
# r    30
# t    40
# h    50
# dtype: int64

# %%
s.loc['k']
# Out:
# k    10
# k    20
# dtype: int64

# %%
print(s.iloc[1])
# Out:
# 20

# %%
#create data name,age,DOB
data=[['karthikakumaravel',19,'29-11-2003'],['yuvaranii',17,None],['Mohankumar',16,'22-02-2008']]
data
# Out:
# [['karthikakumaravel', 19, '29-11-2003'],
#  ['yuvaranii', 17, None],
#  ['Mohankumar', 16, '22-02-2008']]

# %%
df=pd.DataFrame(data)
df
# Out:
#                    0   1           2
# 0  karthikakumaravel  19  29-11-2003
# 1          yuvaranii  17        None
# 2         Mohankumar  16  22-02-2008

# %%
df[0:2]
# Out:
#                    0   1           2
# 0  karthikakumaravel  19  29-11-2003
# 1          yuvaranii  17        None

# %%
df[0][0]
# Out:
# 'karthikakumaravel'

# %%
df[[0,2]]
# Out:
#                    0           2
# 0  karthikakumaravel  29-11-2003
# 1          yuvaranii        None
# 2         Mohankumar  22-02-2008

# %%
df[0][2]
# Out:
# 'Mohankumar'

# %%
df[0][1]
# Out:
# 'yuvaranii'

# %%
df[1:2]
# Out:
#            0   1     2
# 1  yuvaranii  17  None

# %%
df=pd.DataFrame(data,columns=['name','age','dob'])
df
# Out:
#                 name  age         dob
# 0  karthikakumaravel   19  29-11-2003
# 1          yuvaranii   17        None
# 2         Mohankumar   16  22-02-2008

# %%
#df['name']
df['age']
#df[0:1]
# Out:
# 0    19
# 1    17
# 2    16
# Name: age, dtype: int64

# %%
df['name'][0]
# Out:
# 'karthikakumaravel'

# %%
df.loc[2,'name']
df.loc[1,'name']
df.loc[0,'name']
# Out:
# 'karthikakumaravel'

# %%
df.iloc[:0]
# Out:
# Empty DataFrame
# Columns: [name, age, dob]
# Index: []

# %%
df.iloc[0:1] #since we created columns name it get accessed using attribute
# Out:
#                 name  age         dob
# 0  karthikakumaravel   19  29-11-2003

# %%
s=pd.Series([1,2,3])
s.plot()
# Out:
# <Axes: >

# %%
s.hist(bins=3)
# Out:
# <Axes: >

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
#convert above series to numpy -->we can convert
s.to_numpy()
# Out:
# array([1, 2, 3])

# %%
#now we can check the above series s
type(s)
# Out:
# pandas.core.series.Series

# %%
df.head()#first 5 rows
print(df.head(2)) #first 2
# Out:
#                 name  age         dob
# 0  karthikakumaravel   19  29-11-2003
# 1          yuvaranii   17        None

# %%
#df.tail(-3)
df.tail(-2)
# Out:
#          name  age         dob
# 2  Mohankumar   16  22-02-2008

# %%
# None,' ','','-','?','Nil',np.nan(not a number)

# %%
df
# Out:
#                 name  age         dob
# 0  karthikakumaravel   19  29-11-2003
# 1          yuvaranii   17        None
# 2         Mohankumar   16  22-02-2008

# %%
df.isnull().sum()
# Out:
# 0    0
# 1    2
# 2    4
# dtype: int64

# %%
da=[['karthi',20,'26jul'],['jay',None,'28sept'],['kows',19,'oct19'],['rajesh',19,None],['mal',None,None],['ambi',None,None],['rose',20,None]]
df=pd.DataFrame(da,columns=['name','age','D.O.B'])
df
# Out:
#      name   age   D.O.B
# 0  karthi  20.0   26jul
# 1     jay   NaN  28sept
# 2    kows  19.0   oct19
# 3  rajesh  19.0    None
# 4     mal   NaN    None
# 5    ambi   NaN    None
# 6    rose  20.0    None

# %%
df.isnull().sum()
# Out:
# name     0
# age      3
# D.O.B    4
# dtype: int64

# %%
df.dropna()
# Out:
#      name   age  D.O.B
# 0  karthi  20.0  26jul
# 2    kows  19.0  oct19

# %%
df.dropna(inplace=True)
df

# %%
da=[['karthi',20,'26jul'],['jay',None,'28sept'],['kows',19,'oct19'],['rajesh',19,None],['mal',None,None],['ambi',None,None],['rose',20,None]]
df=pd.DataFrame(da,columns=['name','age','D.O.B'])
df.drop(6,axis=0,inplace=True)
#axis=1 means column,axis=0 means row

# %%
df
# Out:
#      name   age   D.O.B
# 0  karthi  20.0   26jul
# 1     jay   NaN  28sept
# 2    kows  19.0   oct19
# 3  rajesh  19.0    None
# 4     mal   NaN    None
# 5    ambi   NaN    None

# %%
print(df)
print()
print(df.drop([1,4,5]))#here only this row need to be deleted
print()
print(df.drop(['age','name'],axis=1))
# Out:
#      name   age   D.O.B
# 0  karthi  20.0   26jul
# 1     jay   NaN  28sept
# 2    kows  19.0   oct19
# 3  rajesh  19.0    None
# 4     mal   NaN    None
# 5    ambi   NaN    None
#
#      name   age  D.O.B
# 0  karthi  20.0  26jul
# 2    kows  19.0  oct19
# 3  rajesh  19.0   None
#
#     D.O.B
# 0   26jul
# 1  28sept
# 2   oct19
# 3    None
# 4    None
# 5    None

# %%
print(df)
df.info()
# Out:
#      name   age   D.O.B
# 0  karthi  20.0   26jul
# 1     jay   NaN  28sept
# 2    kows  19.0   oct19
# 3  rajesh  19.0    None
# 4     mal   NaN    None
# 5    ambi   NaN    None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     3 non-null      float64
#  2   D.O.B   3 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 272.0+ bytes

# %%
df['name'].str.contains('e')
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# Name: name, dtype: bool

# %%
df['name'].str.contains('e')

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (6, 3)
# 18
# [RangeIndex(start=0, stop=6, step=1), Index(['name', 'age', 'D.O.B'], dtype='object')]
# 2
# name      object
# age      float64
# D.O.B     object
# dtype: object
# RangeIndex(start=0, stop=6, step=1)
# Index(['name', 'age', 'D.O.B'], dtype='object')
# [['karthi' 20.0 '26jul']
#  ['jay' nan '28sept']
#  ['kows' 19.0 'oct19']
#  ['rajesh' 19.0 None]
#  ['mal' nan None]
#  ['ambi' nan None]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     3 non-null      float64
#  2   D.O.B   3 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 272.0+ bytes

# %%
df.tail()
# Out:
#      name   age   D.O.B
# 1     jay   NaN  28sept
# 2    kows  19.0   oct19
# 3  rajesh  19.0    None
# 4     mal   NaN    None
# 5    ambi   NaN    None

# %%
print(df)
df2=pd.concat(df,df)
print(df2)
print(dfc=pd.copy(df))
# Out:
#      name   age   D.O.B
# 0  karthi  20.0   26jul
# 1     jay   NaN  28sept
# 2    kows  19.0   oct19
# 3  rajesh  19.0    None
# 4     mal   NaN    None
# 5    ambi   NaN    None
# <ipython-input-196-e50fa3dfa6e3>:2: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df2=pd.concat(df,df)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-196-e50fa3dfa6e3> in <cell line: 2>()
#       1 print(df)
# ----> 2 df2=pd.concat(df,df)
#       3 print(df2)
#       4 print(dfc=pd.copy(df))
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     401     ) -> None:
#     402         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
# --> 403             raise TypeError(
#     404                 "first argument must be an iterable of pandas "
#     405                 f'objects, you passed an object of type "{type(objs).__name__}"'
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   19.333333
# std     0.577350
# min    19.000000
# 25%    19.000000
# 50%    19.000000
# 75%    19.500000
# max    20.000000

# %%
df1=df.describe(include="all")
df1
# Out:
#           name        age  D.O.B
# count        6   3.000000      3
# unique       6        NaN      3
# top     karthi        NaN  26jul
# freq         1        NaN      1
# mean       NaN  19.333333    NaN
# std        NaN   0.577350    NaN
# min        NaN  19.000000    NaN
# 25%        NaN  19.000000    NaN
# 50%        NaN  19.000000    NaN
# 75%        NaN  19.500000    NaN
# max        NaN  20.000000    NaN

# %%
df[['name','age']] #within bracket
# Out:
#      name   age
# 0  karthi  20.0
# 1     jay   NaN
# 2    kows  19.0
# 3  rajesh  19.0
# 4     mal   NaN
# 5    ambi   NaN

# %%
#f[['name[0]','age']]
df.loc[0][0]
# Out:
# 'karthi'

# %%
df.loc[0,'name']
# Out:
# 'karthi'

# %%
df.loc[2,'name']
# Out:
# 'kows'

# %%
df.iloc[1,1] #fisrt argument is first attribute,second argument is second attribute
# Out:
# nan

# %%
df=pd.DataFrame(data,columns=['name','age','dob'])
df
# Out:
#                 name  age         dob
# 0  karthikakumaravel   19  29-11-2003
# 1          yuvaranii   17        None
# 2         Mohankumar   16  22-02-2008

# %%
df.iloc[0,2]
# Out:
# '29-11-2003'

# %%
#df["dob"][1]='29-11'

# %%
a
# Out:
# array([1, 2, 3])

# %%
print(a)
# Out:
# [1 2 3]

# %%
a>40
# Out:
# array([False, False, False])

# %%
a<2
# Out:
# array([ True, False, False])

# %%
print(a[a%2!=0])
# Out:
# [1 3]

# %%
print(a[a%2==0])
# Out:
# [2]

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/Tiger")

# %%
type(df)
# Out:
# list

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
#null value- mode,mean,median
type(df.item_name)
# Out:
# pandas.core.series.Series

# %%
type(df.item_price[0])
# Out:
# str

# %%
#(oldvalue,newvalue)
#df.item_price=df.item_price.str.replace('$','')
#df.head(10)

# %%
#df.item_price=df.item_price.astype(int) #converting the float as int
#df

# %%
#type(df.item_price[1])

# %%
#df.item_price=df.item_price.astype(int) #converting the float as int
#print(df.item_price*100)

# %%
df.item_price=df.item_price.astype(float) #converting the float as same as float
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN         2.0
# 1                                          [Clementine]         3.0
# 2                                               [Apple]         3.0
# 3                                                   NaN         2.0
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...        16.0
# ...                                                 ...         ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...        11.0
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...        11.0
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        11.0
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...         8.0
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...         8.0
#
# [4622 rows x 5 columns]

# %%
#print(df.item_price*100)
#print(type(df))

# %%
df_drink=df[df.item_price < 2]
df_drink
# Out:
#       order_id  quantity          item_name choice_description  item_price
# 28          14         1        Canned Soda       [Dr. Pepper]         1.0
# 53          24         1        Canned Soda           [Sprite]         1.0
# 107         47         1        Canned Soda       [Dr. Pepper]         1.0
# 117         51         1        Canned Soda  [Diet Dr. Pepper]         1.0
# 126         55         1        Canned Soda        [Coca Cola]         1.0
# ...        ...       ...                ...                ...         ...
# 4585      1823         1  Canned Soft Drink        [Diet Coke]         1.0
# 4597      1826         1  Canned Soft Drink           [Nestea]         1.0
# 4601      1827         1  Canned Soft Drink        [Diet Coke]         1.0
# 4606      1828         1  Canned Soft Drink             [Coke]         1.0
# 4609      1829         1  Canned Soft Drink           [Sprite]         1.0
#
# [348 rows x 5 columns]

# %%
df_drink.item_name.unique()
# Out:
# array(['Canned Soda', 'Canned Soft Drink'], dtype=object)

# %%
df_drink.item_name.nunique()
# Out:
# 2

# %%
df_drink.item_name.value_counts()
# Out:
# Canned Soft Drink    264
# Canned Soda           84
# Name: item_name, dtype: int64

# %%
#canned soda - full details to be needed
df[df.item_name=='Canned Soda']
# Out:
#       order_id  quantity    item_name choice_description  item_price
# 18           9         2  Canned Soda           [Sprite]         2.0
# 28          14         1  Canned Soda       [Dr. Pepper]         1.0
# 51          23         2  Canned Soda     [Mountain Dew]         2.0
# 53          24         1  Canned Soda           [Sprite]         1.0
# 107         47         1  Canned Soda       [Dr. Pepper]         1.0
# ...        ...       ...          ...                ...         ...
# 3897      1562         1  Canned Soda     [Mountain Dew]         1.0
# 3926      1575         1  Canned Soda       [Dr. Pepper]         1.0
# 3936      1578         1  Canned Soda  [Diet Dr. Pepper]         1.0
# 4008      1604         1  Canned Soda        [Diet Coke]         1.0
# 4051      1621         1  Canned Soda           [Sprite]         1.0
#
# [104 rows x 5 columns]

# %%
#only i need choice_description of the canned soda
df[df.item_name=='Canned Soda'].choice_description.value_counts()
# Out:
# [Coca Cola]          26
# [Dr. Pepper]         18
# [Sprite]             17
# [Mountain Dew]       15
# [Diet Coke]          15
# [Diet Dr. Pepper]    13
# Name: choice_description, dtype: int64

# %%
#need no of uniqque values count
df[df.item_name=='Canned Soda'].choice_description.nunique()
# Out:
# 6

# %%
df[df.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
df.dropna(inplace=True) #drop to remove the null values

# %%
df[df.choice_description.str.contains('Black Beans')].item_name
# Out:
# 4               Chicken Bowl
# 7              Steak Burrito
# 9              Steak Burrito
# 11      Chicken Crispy Tacos
# 12        Chicken Soft Tacos
#                 ...
# 4604            Chicken Bowl
# 4608          Veggie Burrito
# 4611          Veggie Burrito
# 4612           Carnitas Bowl
# 4617           Steak Burrito
# Name: item_name, Length: 1345, dtype: object

# %%
df[df.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df.item_price<10)&(df.item_name=='Chicken Bowl')]
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...         8.0
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...         8.0
# 76    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...         8.0
# 78    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...         8.0
# 99    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...         8.0
# ...                                                 ...         ...
# 4583  [Tomatillo Green Chili Salsa, [Rice, Black Bea...         8.0
# 4591  [Tomatillo Red Chili Salsa, [Rice, Black Beans...         8.0
# 4595  [Tomatillo Green Chili Salsa, [Rice, Black Bea...         8.0
# 4599      [Roasted Chili Corn Salsa, [Cheese, Lettuce]]         8.0
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...         8.0
#
# [422 rows x 5 columns]

# %%
df[(df.item_price<10)&(df.item_name=='Chicken Bowl')].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 3107      1240         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3087      1230         1  Chicken Bowl
# 3076      1225         1  Chicken Bowl
# ...        ...       ...           ...
# 1651       667         1  Chicken Bowl
# 1649       667         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...         8.0
# 3107  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...         8.0
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...         8.0
# 3087  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...         8.0
# 3076  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...         8.0
# ...                                                 ...         ...
# 1651  [Roasted Chili Corn Salsa (Medium), [Rice, Che...         8.0
# 1649  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...         8.0
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...         8.0
# 1829    [Fresh Tomato Salsa, [Fajita Vegetables, Rice]]         8.0
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...         8.0
#
# [422 rows x 5 columns]

# %%
df=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df[(df.star_rating>=9)&(df.content_rating=='PG-13')]
# Out:
#    star_rating            title content_rating   genre  duration  \
# 3          9.0  The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
df[(df.star_rating>=8)&(df.content_rating=='PG-13')].sort_values(['duration'])
# Out:
#      star_rating                                              title  \
# 175          8.2                                      Touch of Evil
# 305          8.0                                         Persepolis
# 232          8.1                                  Chungking Express
# 356          8.0                                         The Artist
# 279          8.1                    The Perks of Being a Wallflower
# 370          8.0                             Hannah and Her Sisters
# 314          8.0                            Crimes and Misdemeanors
# 379          8.0                                Edward Scissorhands
# 191          8.2                                    The Sixth Sense
# 286          8.1                  The Diving Bell and the Butterfly
# 391          8.0                                   Edge of Tomorrow
# 209          8.1                                 The Imitation Game
# 240          8.1                               The Bourne Ultimatum
# 25           8.6                                  Life Is Beautiful
# 366          8.0                                           Serenity
# 196          8.1                            Guardians of the Galaxy
# 180          8.2                                       Hotel Rwanda
# 73           8.4                            Jodaeiye Nader az Simin
# 310          8.0                                           Big Fish
# 260          8.1                                     The Sea Inside
# 377          8.0                             The Fault in Our Stars
# 312          8.0                                          Star Trek
# 118          8.3                 Indiana Jones and the Last Crusade
# 299          8.0                                      Jurassic Park
# 270          8.1                                    Wings of Desire
# 53           8.5                                       The Prestige
# 211          8.1                                         Departures
# 222          8.1       Harry Potter and the Deathly Hallows: Part 2
# 248          8.1                         X-Men: Days of Future Past
# 227          8.1                                Million Dollar Baby
# 69           8.4                                  Princess Mononoke
# 170          8.2                                   A Beautiful Mind
# 301          8.0                                          Furious 7
# 113          8.3                                      Batman Begins
# 146          8.2                                            Warrior
# 340          8.0                                Catch Me If You Can
# 13           8.8                                       Forrest Gump
# 271          8.1  Pirates of the Caribbean: The Curse of the Bla...
# 177          8.2                                       The Avengers
# 341          8.0                                     Cinderella Man
# 380          8.0                                      Casino Royale
# 259          8.1                                           The Help
# 11           8.8                                          Inception
# 3            9.0                                    The Dark Knight
# 359          8.0                The Hobbit: The Desolation of Smaug
# 373          8.0                                    My Name Is Khan
# 43           8.5                              The Dark Knight Rises
# 15           8.7                                       Interstellar
# 362          8.0                  The Hobbit: An Unexpected Journey
# 60           8.5                                           3 Idiots
# 26           8.6                       Once Upon a Time in the West
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 339          8.0                                 Dances with Wolves
# 335          8.0                                     Doctor Zhivago
# 385          8.0                                          Spartacus
# 7            8.9      The Lord of the Rings: The Return of the King
#
#     content_rating      genre  duration  \
# 175          PG-13      Crime        95
# 305          PG-13  Animation        96
# 232          PG-13      Drama        98
# 356          PG-13     Comedy       100
# 279          PG-13      Drama       102
# 370          PG-13     Comedy       103
# 314          PG-13     Comedy       104
# 379          PG-13      Drama       105
# 191          PG-13      Drama       107
# 286          PG-13  Biography       112
# 391          PG-13     Action       113
# 209          PG-13  Biography       114
# 240          PG-13     Action       115
# 25           PG-13     Comedy       116
# 366          PG-13     Action       119
# 196          PG-13     Action       121
# 180          PG-13      Drama       121
# 73           PG-13      Drama       123
# 310          PG-13  Adventure       125
# 260          PG-13  Biography       125
# 377          PG-13      Drama       126
# 312          PG-13     Action       127
# 118          PG-13     Action       127
# 299          PG-13  Adventure       127
# 270          PG-13      Drama       128
# 53           PG-13      Drama       130
# 211          PG-13      Drama       130
# 222          PG-13  Adventure       130
# 248          PG-13     Action       131
# 227          PG-13      Drama       132
# 69           PG-13  Animation       134
# 170          PG-13  Biography       135
# 301          PG-13     Action       137
# 113          PG-13     Action       140
# 146          PG-13      Drama       140
# 340          PG-13  Biography       141
# 13           PG-13      Drama       142
# 271          PG-13  Adventure       143
# 177          PG-13     Action       143
# 341          PG-13  Biography       144
# 380          PG-13     Action       144
# 259          PG-13      Drama       146
# 11           PG-13     Action       148
# 3            PG-13     Action       152
# 359          PG-13  Adventure       161
# 373          PG-13      Drama       165
# 43           PG-13     Action       165
# 15           PG-13  Adventure       169
# 362          PG-13  Adventure       169
# 60           PG-13     Comedy       170
# 26           PG-13    Western       175
# 10           PG-13  Adventure       178
# 14           PG-13  Adventure       179
# 339          PG-13  Adventure       181
# 335          PG-13      Drama       197
# 385          PG-13     Action       197
# 7            PG-13  Adventure       201
#
#                                            actors_list
# 175  [u'Charlton Heston', u'Orson Welles', u'Janet ...
# 305  [u'Chiara Mastroianni', u'Catherine Deneuve', ...
# 232  [u'Brigitte Lin', u'Takeshi Kaneshiro', u'Tony...
# 356  [u'Jean Dujardin', u'B\xe9r\xe9nice Bejo', u'J...
# 279  [u'Logan Lerman', u'Emma Watson', u'Ezra Miller']
# 370  [u'Mia Farrow', u'Dianne Wiest', u'Michael Cai...
# 314  [u'Martin Landau', u'Woody Allen', u'Bill Bern...
# 379  [u'Johnny Depp', u'Winona Ryder', u'Dianne Wie...
# 191  [u'Bruce Willis', u'Haley Joel Osment', u'Toni...
# 286  [u'Mathieu Amalric', u'Emmanuelle Seigner', u'...
# 391    [u'Tom Cruise', u'Emily Blunt', u'Bill Paxton']
# 209  [u'Benedict Cumberbatch', u'Keira Knightley', ...
# 240  [u'Matt Damon', u'\xc9dgar Ram\xedrez', u'Joan...
# 25   [u'Roberto Benigni', u'Nicoletta Braschi', u'G...
# 366  [u'Nathan Fillion', u'Gina Torres', u'Chiwetel...
# 196  [u'Chris Pratt', u'Vin Diesel', u'Bradley Coop...
# 180  [u'Don Cheadle', u'Sophie Okonedo', u'Joaquin ...
# 73   [u'Peyman Moaadi', u'Leila Hatami', u'Sareh Ba...
# 310  [u'Ewan McGregor', u'Albert Finney', u'Billy C...
# 260  [u'Javier Bardem', u'Bel\xe9n Rueda', u'Lola D...
# 377  [u'Shailene Woodley', u'Ansel Elgort', u'Nat W...
# 312  [u'Chris Pine', u'Zachary Quinto', u'Simon Pegg']
# 118  [u'Harrison Ford', u'Sean Connery', u'Alison D...
# 299    [u'Sam Neill', u'Laura Dern', u'Jeff Goldblum']
# 270  [u'Bruno Ganz', u'Solveig Dommartin', u'Otto S...
# 53   [u'Christian Bale', u'Hugh Jackman', u'Scarlet...
# 211  [u'Masahiro Motoki', u'Ry\xf4ko Hirosue', u'Ts...
# 222  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 248  [u'Patrick Stewart', u'Ian McKellen', u'Hugh J...
# 227  [u'Hilary Swank', u'Clint Eastwood', u'Morgan ...
# 69   [u'Y\xf4ji Matsuda', u'Yuriko Ishida', u'Y\xfb...
# 170  [u'Russell Crowe', u'Ed Harris', u'Jennifer Co...
# 301  [u'Vin Diesel', u'Paul Walker', u'Dwayne Johns...
# 113  [u'Christian Bale', u'Michael Caine', u'Ken Wa...
# 146    [u'Tom Hardy', u'Nick Nolte', u'Joel Edgerton']
# 340  [u'Leonardo DiCaprio', u'Tom Hanks', u'Christo...
# 13     [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']
# 271  [u'Johnny Depp', u'Geoffrey Rush', u'Orlando B...
# 177  [u'Robert Downey Jr.', u'Chris Evans', u'Scarl...
# 341  [u'Russell Crowe', u'Ren\xe9e Zellweger', u'Cr...
# 380     [u'Daniel Craig', u'Eva Green', u'Judi Dench']
# 259  [u'Emma Stone', u'Viola Davis', u'Octavia Spen...
# 11   [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 359  [u'Ian McKellen', u'Martin Freeman', u'Richard...
# 373    [u'Shah Rukh Khan', u'Kajol', u'Sheetal Menon']
# 43   [u'Christian Bale', u'Tom Hardy', u'Anne Hatha...
# 15   [u'Matthew McConaughey', u'Anne Hathaway', u'J...
# 362  [u'Martin Freeman', u'Ian McKellen', u'Richard...
# 60         [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 26   [u'Henry Fonda', u'Charles Bronson', u'Claudia...
# 10   [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 14   [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# 339  [u'Kevin Costner', u'Mary McDonnell', u'Graham...
# 335  [u'Omar Sharif', u'Julie Christie', u'Geraldin...
# 385  [u'Kirk Douglas', u'Laurence Olivier', u'Jean ...
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...

# %%
df[df.actors_list.str.contains('Daniel Radcliffe')].title
# Out:
# 222    Harry Potter and the Deathly Hallows: Part 2
# 551        Harry Potter and the Prisoner of Azkaban
# 642    Harry Potter and the Deathly Hallows: Part 1
# 727             Harry Potter and the Goblet of Fire
# 891          Harry Potter and the Half-Blood Prince
# 909           Harry Potter and the Sorcerer's Stone
# 932       Harry Potter and the Order of the Phoenix
# Name: title, dtype: object

# %%
df[df.actors_list.str.contains('Daniel Radcliffe')].sort_values(['duration' and 'star_rating'])
# Out:
#      star_rating                                         title content_rating  \
# 932          7.4     Harry Potter and the Order of the Phoenix          PG-13
# 891          7.5        Harry Potter and the Half-Blood Prince             PG
# 909          7.5         Harry Potter and the Sorcerer's Stone             PG
# 727          7.6           Harry Potter and the Goblet of Fire          PG-13
# 642          7.7  Harry Potter and the Deathly Hallows: Part 1          PG-13
# 551          7.8      Harry Potter and the Prisoner of Azkaban             PG
# 222          8.1  Harry Potter and the Deathly Hallows: Part 2          PG-13
#
#          genre  duration                                        actors_list
# 932  Adventure       138  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 891  Adventure       153  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 909  Adventure       152  [u'Daniel Radcliffe', u'Rupert Grint', u'Richa...
# 727  Adventure       157  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 642  Adventure       146  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 551  Adventure       142  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 222  Adventure       130  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...

# %%
df[df.actors_list.str.contains('Daniel Radcliffe')].sort_values(['duration'])
# Out:
#      star_rating                                         title content_rating  \
# 222          8.1  Harry Potter and the Deathly Hallows: Part 2          PG-13
# 932          7.4     Harry Potter and the Order of the Phoenix          PG-13
# 551          7.8      Harry Potter and the Prisoner of Azkaban             PG
# 642          7.7  Harry Potter and the Deathly Hallows: Part 1          PG-13
# 909          7.5         Harry Potter and the Sorcerer's Stone             PG
# 891          7.5        Harry Potter and the Half-Blood Prince             PG
# 727          7.6           Harry Potter and the Goblet of Fire          PG-13
#
#          genre  duration                                        actors_list
# 222  Adventure       130  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 932  Adventure       138  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 551  Adventure       142  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 642  Adventure       146  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 909  Adventure       152  [u'Daniel Radcliffe', u'Rupert Grint', u'Richa...
# 891  Adventure       153  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 727  Adventure       157  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...

# %%
df[df.actors_list.str.contains('Daniel Radcliffe')].sort_values(['star_rating','duration'],ascending=[False,True])
# Out:
#      star_rating                                         title content_rating  \
# 222          8.1  Harry Potter and the Deathly Hallows: Part 2          PG-13
# 551          7.8      Harry Potter and the Prisoner of Azkaban             PG
# 642          7.7  Harry Potter and the Deathly Hallows: Part 1          PG-13
# 727          7.6           Harry Potter and the Goblet of Fire          PG-13
# 909          7.5         Harry Potter and the Sorcerer's Stone             PG
# 891          7.5        Harry Potter and the Half-Blood Prince             PG
# 932          7.4     Harry Potter and the Order of the Phoenix          PG-13
#
#          genre  duration                                        actors_list
# 222  Adventure       130  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 551  Adventure       142  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 642  Adventure       146  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 727  Adventure       157  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 909  Adventure       152  [u'Daniel Radcliffe', u'Rupert Grint', u'Richa...
# 891  Adventure       153  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 932  Adventure       138  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...

# %%
ufo=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# 18236  12/31/2000 23:00
# 18237  12/31/2000 23:00
# 18238  12/31/2000 23:45
# 18239  12/31/2000 23:45
# 18240  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %%
ufo.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
ufo['Shape Reported'].isnull().sum()

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
dff=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
dff
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# 2                             0.7         Africa
# 3                            12.4         Europe
# 4                             5.9         Africa
# ..                            ...            ...
# 188                           7.7  South America
# 189                           2.0           Asia
# 190                           0.1           Asia
# 191                           2.5         Africa
# 192                           4.7         Africa
#
# [193 rows x 6 columns]

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
dff.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
dff.beer_servings.min()
# Out:
# 0

# %%
dff.beer_servings.max()
# Out:
# 376

# %%
dff[dff.continent=='Asia']
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 19                 Bhutan             23                0              0
# 24                 Brunei             31                2              1
# 30               Cambodia             57               65              1
# 36                  China             79              192              8
# 46            North Korea              0                0              0
# 77                  India              9              114              0
# 78              Indonesia              5                1              0
# 79                   Iran              0                0              0
# 80                   Iraq              9                3              0
# 82                 Israel             63               69              9
# 85                  Japan             77              202             16
# 86                 Jordan              6               21              1
# 87             Kazakhstan            124              246             12
# 90                 Kuwait              0                0              0
# 91             Kyrgyzstan             31               97              6
# 92                   Laos             62                0            123
# 94                Lebanon             20               55             31
# 102              Malaysia             13                4              0
# 103              Maldives              0                0              0
# 112              Mongolia             77              189              8
# 116               Myanmar              5                1              0
# 119                 Nepal              5                6              0
# 127                  Oman             22               16              1
# 128              Pakistan              0                0              0
# 134           Philippines             71              186              1
# 137                 Qatar              1               42              7
# 138           South Korea            140               16              9
# 141    Russian Federation            247              326             73
# 149          Saudi Arabia              0                5              0
# 154             Singapore             60               12             11
# 161             Sri Lanka             16              104              0
# 167                 Syria              5               35             16
# 168            Tajikistan              2               15              0
# 169              Thailand             99              258              1
# 171           Timor-Leste              1                1              4
# 176                Turkey             51               22              7
# 177          Turkmenistan             19               71             32
# 181  United Arab Emirates             16              135              5
# 186            Uzbekistan             25              101              8
# 189               Vietnam            111                2              1
# 190                 Yemen              6                0              0
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0      Asia
# 12                            2.0      Asia
# 13                            0.0      Asia
# 19                            0.4      Asia
# 24                            0.6      Asia
# 30                            2.2      Asia
# 36                            5.0      Asia
# 46                            0.0      Asia
# 77                            2.2      Asia
# 78                            0.1      Asia
# 79                            0.0      Asia
# 80                            0.2      Asia
# 82                            2.5      Asia
# 85                            7.0      Asia
# 86                            0.5      Asia
# 87                            6.8      Asia
# 90                            0.0      Asia
# 91                            2.4      Asia
# 92                            6.2      Asia
# 94                            1.9      Asia
# 102                           0.3      Asia
# 103                           0.0      Asia
# 112                           4.9      Asia
# 116                           0.1      Asia
# 119                           0.2      Asia
# 127                           0.7      Asia
# 128                           0.0      Asia
# 134                           4.6      Asia
# 137                           0.9      Asia
# 138                           9.8      Asia
# 141                          11.5      Asia
# 149                           0.1      Asia
# 154                           1.5      Asia
# 161                           2.2      Asia
# 167                           1.0      Asia
# 168                           0.3      Asia
# 169                           6.4      Asia
# 171                           0.1      Asia
# 176                           1.4      Asia
# 177                           2.2      Asia
# 181                           2.8      Asia
# 186                           2.4      Asia
# 189                           2.0      Asia
# 190                           0.1      Asia

# %%
dff[dff.continent=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
dff[dff.continent.str.contains('Asia')].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
dff[dff.continent.str.contains('Asia')].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
dff.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
dff[dff.continent.str.contains('Asia')].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
dff.groupby('continent').beer_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333

# %%
https://t.ly/HIwPM
# Out:
#   File "<ipython-input-138-847a176a6aa8>", line 1
#     https://t.ly/HIwPM
#           ^
# SyntaxError: invalid syntax
